# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  750000

# %%
plt.scatter(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.scatter(df)
#
# File C:\Python312\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
plt.scatter(df.area,df.price, color="red", marker="+")
plt.xlabel("Area")
plt.ylabel("Prices")
# Out:
# Text(0, 0.5, 'Prices')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.prices)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29796\3272446412.py in ?()
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(df[['area']],df.prices)
#
# C:\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'prices'

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(3300)
# Out:
# C:\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 reg.predict(3300)
#
# File C:\Python312\Lib\site-packages\sklearn\linear_model\_base.py:355, in MultiOutputLinearModel.predict(self, X)
#     341 def predict(self, X):
#     342     """
#     343     Predict using the linear model.
#     344
#    (...)
#     353         Predicted values.
#     354     """
# --> 355     return super().predict(X)
#
# File C:\Python312\Lib\site-packages\sklearn\linear_model\_base.py:316, in LinearModel.predict(self, X)
#     302 """
#     303 Predict using the linear model.
#     304
#    (...)
#     313     Predicted values.
#     314 """
#     315 check_same_namespace(X, self, attribute="coef_", method="predict")
# --> 316 return self._decision_function(X)
#
# File C:\Python312\Lib\site-packages\sklearn\linear_model\_base.py:294, in LinearModel._decision_function(self, X)
#     291 def _decision_function(self, X):
#     292     check_is_fitted(self)
# --> 294     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     295     coef_ = self.coef_
#     296     if coef_.ndim == 1:
#
# File C:\Python312\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File C:\Python312\Lib\site-packages\sklearn\utils\validation.py:1050, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1047 if ensure_2d:
#    1048     # If input is scalar raise error
#    1049     if array.ndim == 0:
# -> 1050         raise ValueError(
#    1051             "Expected 2D array, got scalar array instead:\narray={}.\n"
#    1052             "Reshape your data either using array.reshape(-1, 1) if "
#    1053             "your data has a single feature or array.reshape(1, -1) "
#    1054             "if it contains a single sample.".format(array)
#    1055         )
#    1056     # If input is 1D raise error
#    1057     if array.ndim == 1:
#    1058         # If input is a Series-like object (eg. pandas Series or polars Series)
#
# ValueError: Expected 2D array, got scalar array instead:
# array=3300.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
reg.predict([[3300]])
# Out:
# C:\Python312\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([634023.97260274])

# %%
reg.coef_
# Out:
# array([151.19863014])

# %%
reg.intercept_
# Out:
# 135068.49315068492

# %%
plt.scatter(df.area,df.price, color="red", marker="+")
plt.xlabel("Area")
plt.ylabel("Price")
plt.plot(df.area, reg.predict(df[['area']]), color="blue")
